# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import  matplotlib.pyplot  as  plt

# %%
pollution_df   =  pd.read_csv('pollution.csv', header = 0, index_col = 0, parse_dates = True, squeeze = True)

# %%
pollution_df
# Out:
#        year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd     Iws  Is  Ir
# No
# 1      2010      1    1     0    NaN   -21 -11.0  1021.0   NW    1.79   0   0
# 2      2010      1    1     1    NaN   -21 -12.0  1020.0   NW    4.92   0   0
# 3      2010      1    1     2    NaN   -21 -11.0  1019.0   NW    6.71   0   0
# 4      2010      1    1     3    NaN   -21 -14.0  1019.0   NW    9.84   0   0
# 5      2010      1    1     4    NaN   -20 -12.0  1018.0   NW   12.97   0   0
# ...     ...    ...  ...   ...    ...   ...   ...     ...  ...     ...  ..  ..
# 43820  2014     12   31    19    8.0   -23  -2.0  1034.0   NW  231.97   0   0
# 43821  2014     12   31    20   10.0   -22  -3.0  1034.0   NW  237.78   0   0
# 43822  2014     12   31    21   10.0   -22  -3.0  1034.0   NW  242.70   0   0
# 43823  2014     12   31    22    8.0   -22  -4.0  1034.0   NW  246.72   0   0
# 43824  2014     12   31    23   12.0   -21  -3.0  1034.0   NW  249.85   0   0
#
# [43824 rows x 12 columns]

# %%
pollution_df.plot()
plt.ylabel('Variaveis')
plt.title('Poluição em Beijing, China')
plt.show()

# %%
values = pollution_df.values

# specify columns to plot

groups = [0, 1, 2, 3, 5, 6, 7]
i = 1

# plot each column
plt.figure()

for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(pollution_df.columns[group], y=0.5, loc='right')
    i += 1
    
plt.show()
