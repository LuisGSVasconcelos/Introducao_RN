# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import  matplotlib.pyplot  as  plt

# %%
tractor_df  =  pd.read_csv('Tractor-Sales.csv', header = 0, index_col = 0, parse_dates = True, squeeze = True)

# %%
tractor_df
# Out:
# Month-Year
# Jan-03    141
# Feb-03    157
# Mar-03    185
# Apr-03    199
# May-03    203
#          ...
# Aug-14    848
# Sep-14    640
# Oct-14    581
# Nov-14    519
# Dec-14    605
# Name: Number of Tractor Sold, Length: 144, dtype: int64

# %%
tractor_df.plot()
plt.ylabel('Tractor Sales')
plt.title("Tractor Sales from 2003 to 2014")
plt.show()
