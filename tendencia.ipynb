# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import  matplotlib.pyplot  as  plt

# %%
series  =  pd.read_csv('shampoo.csv', header = 0, index_col = 0, parse_dates = True, squeeze = True)

# %%
series
# Out:
# Month
# 1-01    266.0
# 1-02    145.9
# 1-03    183.1
# 1-04    119.3
# 1-05    180.3
# 1-06    168.5
# 1-07    231.8
# 1-08    224.5
# 1-09    192.8
# 1-10    122.9
# 1-11    336.5
# 1-12    185.9
# 2-01    194.3
# 2-02    149.5
# 2-03    210.1
# 2-04    273.3
# 2-05    191.4
# 2-06    287.0
# 2-07    226.0
# 2-08    303.6
# 2-09    289.9
# 2-10    421.6
# 2-11    264.5
# 2-12    342.3
# 3-01    339.7
# 3-02    440.4
# 3-03    315.9
# 3-04    439.3
# 3-05    401.3
# 3-06    437.4
# 3-07    575.5
# 3-08    407.6
# 3-09    682.0
# 3-10    475.3
# 3-11    581.3
# 3-12    646.9
# Name: Sales, dtype: float64

# %%
series.plot()
plt.ylabel('Vendas')
plt.title('Vendas de shampoo')
plt.show()
